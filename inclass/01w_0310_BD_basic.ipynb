# %% [markdown]
# <a href="https://colab.research.google.com/github/yeojeong735/2025-1-BD/blob/main/inclass/01w_0310_BD_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.version
# Out:
# '3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]'

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.11/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.11/dist-packages']

# %%
import numpy as np
import pandas as pd

print(np.__version__)
print(np.__version__)
# Out:
# 1.26.4
# 1.26.4

# %% [markdown]
# ## 코랩에서 한글 처리

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 64.9 MB/s eta 0:00:00
# ...

# %%
# 그림 선명하게
# %config InlineBackend.figure_format = 'retina'

# %%
import koreanize_matplotlib
import matplotlib.pyplot as plt

plt.plot([-3, 1, 5, 6])
plt.title('그래프 제목', fontweight='bold')
plt.xlabel('x축')
plt.show()

# %% [markdown]
# ## 시리즈 개요

# %%
s = pd.Series([1,3, 5, np.nan, 6,8], name='first')
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# Name: first, dtype: float64

# %%
print(s.name)
print(s.index)
print(s.values)
print(s.shape)
print(s.size)
# Out:
# first
# RangeIndex(start=0, stop=6, step=1)
# [ 1.  3.  5. nan  6.  8.]
# (6,)
# 6

# %%
s[0]
# Out:
# 1.0

# %%
s[3]
# Out:
# nan

# %%
s[1:5]
# Out:
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# Name: first, dtype: float64

# %%
s[2]
# Out:
# 5.0

# %%
s.index = list('abcdef')

# %%
s
# Out:
# a    1.0
# b    3.0
# c    5.0
# d    NaN
# e    6.0
# f    8.0
# Name: first, dtype: float64

# %%
s1 = s[1:4]
s1
# Out:
# b    3.0
# c    5.0
# d    NaN
# Name: first, dtype: float64

# %%
s[1:5] #원래 첨자로 슬라이싱
# Out:
# b    3.0
# c    5.0
# d    NaN
# e    6.0
# Name: first, dtype: float64

# %% [markdown]
# ## 시리즈 고급 인덱싱

# %%
age = pd.Series([9,17,43,63,85], index=list('abcde'), name = 'age')
age
# Out:
# a     9
# b    17
# c    43
# d    63
# e    85
# Name: age, dtype: int64

# %%
age[[1,3,4]]
# Out:
# <ipython-input-23-05c263ba1af0>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   age[[1,3,4]]
# b    17
# d    63
# e    85
# Name: age, dtype: int64

# %% [markdown]
# ## 불리안 인덱싱

# %%
s = pd.Series([3,6,-3,0,-4,3])
s
# Out:
# 0    3
# 1    6
# 2   -3
# 3    0
# 4   -4
# 5    3
# dtype: int64

# %%
s > 0
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
s[s>0]
# Out:
# 0    3
# 1    6
# 5    3
# dtype: int64

# %% [markdown]
# ## the end
